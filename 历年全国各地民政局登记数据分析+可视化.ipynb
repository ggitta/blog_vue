# %% [markdown]
# * 🔱 **大家好，我是 ** 👉  [**Python当打之年**](https://www.heywhale.com/home/user/profile/60af51b775d38a00171a954a)
# * 🛴 为了页面整洁，部分代码已隐藏，如需要查看代码请 "**点击右上角的 Fork**" 然后点击 "**运行**" 选择右上角的 "**查看**" 选择 "**隐藏/显示 所有代码输入**"，保存即可
# * 🚀 欢迎 ** *Fork、点赞*  ~ ~ ~**
#
# ***
#
# * ✨ [**知乎ID**](https://www.zhihu.com/people/ou-zi-19-40/posts)（点击跳转）
# * ✨ [**公众号**](https://mp.weixin.qq.com/mp/appmsgalbum?__biz=Mzg3ODUxOTA3Mg==&action=getalbum&album_id=1744017292910215171#wechat_redirect)（点击跳转）
# * ✨ [**欢迎访问专栏：可视化图鉴**](https://www.heywhale.com/home/column/60e2740e3aeb9c0017b967a2)（点击跳转）
#
# ***
# # 推荐阅读
# * 💑 [**【Pyecharts | 历年全国各地民政局登记数据分析+可视化】**](https://www.heywhale.com/mw/project/611dfe6afe727700176f3e34)
# * 🏆 [**【Pandas+Pyecharts | 2020东京奥运会奖牌数据可视化 】**](https://www.heywhale.com/mw/project/610e2d90fe727700176baac3)
# * 🌏 [**【Pandas+Pyecharts | 全国热门旅游景点数据分析+可视化】**](https://www.heywhale.com/mw/project/6108b591fe72770017694667)
# * 🏹 [**【Pandas常用基础操作指令汇总】**](https://www.heywhale.com/mw/project/60f6688d486e5c00170c845c)
# * 🎯 [**【pandas + pyecharts | ADX游戏广告投放渠道综合分析】**](https://www.heywhale.com/mw/project/60e3a7a6be5f0900176110b1)
# * 🕔 [**【Schedule + Pyecharts | 时间序列图(动态轮播图)】**](https://www.heywhale.com/mw/project/60dd1932ee16460017a49d57)
# * 🏠 [**【Pandas+Pyecharts | 北京某平台二手房数据分析+可视化】**](https://www.heywhale.com/mw/project/60d05c29056f570017c0f756)
# * 🏫 [**【Pandas+Pyecharts | 2021中国大学综合排名分析+可视化】**](https://www.heywhale.com/mw/project/60b742e505a4b30017ded5f6)
# * 🎦 [**【爬虫 | Python爬取豆瓣电影Top250 + 数据可视化】**](https://www.heywhale.com/mw/project/60b051d3d4c4dd0017eab1dc)
# * 📡 [**【技巧 | Python创建自己的高匿代理IP池】**](https://www.heywhale.com/mw/project/60bdf70b3d29eb0017571e72)
#
# ***

# %% [markdown]
# # 1. 导入模块
# ## 升级 pyecharts 包
# 可视化部分需要用到 pyecharts==1.9.0
# 已安装其他低版本的需要升级，如果未安装过pyecharts，直接pip安装就是最新版本

# %%
# !pip install --upgrade pyecharts
# Out:
# Requirement already satisfied: pyecharts in /opt/conda/lib/python3.6/site-packages (1.1.0)
# Collecting pyecharts
#   Downloading pyecharts-1.9.0-py3-none-any.whl (135 kB)
#      |████████████████████████████████| 135 kB 28 kB/s eta 0:00:01
# Requirement already satisfied: prettytable in /opt/conda/lib/python3.6/site-packages (from pyecharts) (0.7.2)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.6/site-packages (from pyecharts) (2.10)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.6/site-packages (from jinja2->pyecharts) (1.1.0)
# Collecting simplejson
#   Downloading simplejson-3.17.3-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (128 kB)
#      |████████████████████████████████| 128 kB 17 kB/s eta 0:00:01
# Installing collected packages: simplejson, pyecharts
#   Attempting uninstall: pyecharts
#     Found existing installation: pyecharts 1.1.0
#     Uninstalling pyecharts-1.1.0:
#       Successfully uninstalled pyecharts-1.1.0
# Successfully installed pyecharts-1.9.0 simplejson-3.17.3
# WARNING: You are using pip version 20.3.3; however, version 21.2.4 is available.
# You should consider upgrading via the '/opt/conda/bin/python -m pip install --upgrade pip' command.

# %%
import pandas as pd
from pyecharts.charts import *
from pyecharts import options as opts
from pyecharts.globals import ThemeType
from pyecharts.globals import SymbolType
from pyecharts.commons.utils import JsCode
from pyecharts.charts import Line,Bar,Page,Map

# %% [markdown]
# # 2. 读取数据
# ## 2.1 结婚登记数据

# %%
df_marry = pd.read_csv('/home/mw/input/202108196091/结婚登记(万对).csv', encoding='gb2312')
df_marry.head()
# Out:
#        地区  2019年  2018年  2017年  2016年  2015年  2014年  2013年  2012年  2011年  \
# 0     北京市  12.90  13.78  15.15  16.62  16.60  17.00  16.37  17.41  17.32
# 1     天津市   9.64   9.75   9.51   9.82  10.12   9.94  10.26  10.14  10.41
# 2     河北省  42.13  45.87  50.49  55.19  60.94  66.13  74.08  74.53  77.72
# 3     山西省  25.50  27.85  28.77  30.01  34.68  35.07  38.40  36.28  33.96
# 4  内蒙古自治区  16.18  17.69  18.70  19.84  21.79  21.68  22.16  20.77  21.53
#
#    2010年  2009年  2008年  2007年  2006年  2005年  2004年  2003年  2002年  2001年
# 0   13.8  18.18  14.75  11.79   17.1    9.7  12.64    9.4    7.6   7.94
# 1    8.7  10.40   8.93   7.57    8.4    6.4   7.70    6.3    5.4   5.79
# 2   75.0  72.00  66.31  60.39   55.5   53.8  57.48   52.4   47.1  44.56
# 3   36.1  34.36  28.74  23.85   20.2   19.0  16.15   14.5   15.4  14.62
# 4   20.3  18.84  18.78  18.57   16.3   15.5  14.77   13.1   13.1  14.76

# %% [markdown]
# ## 2.2 离婚登记数据

# %%
df_divorce = pd.read_csv('/home/mw/input/202108196091/离婚登记(万对).csv', encoding='gb2312')
df_divorce.head()
# Out:
#        地区  2019年  2018年  2017年  2016年  2015年  2014年  2013年  2012年  2011年  \
# 0     北京市   8.38   7.41   8.06  10.58   8.22   6.56   6.46   4.86   4.35
# 1     天津市   7.47   6.41   5.89   6.52   5.19   4.45   4.53   3.63   3.21
# 2     河北省  25.57  23.45  23.24  22.02  19.90  18.57  17.88  17.12  15.63
# 3     山西省   9.12   8.75   8.22   7.65   7.22   6.56   6.10   5.28   4.75
# 4  内蒙古自治区   9.98   9.88  10.09   9.84   9.19   8.84   8.07   7.06   6.67
#
#    2010年  2009年  2008年  2007年  2006年  2005年  2004年  2003年  2002年  2001年
# 0    4.4   4.13   3.76   3.66    3.6    3.4    3.3    3.1    2.8   2.77
# 1    3.0   2.76   2.40   2.21    2.1    1.9    1.8    1.4    1.2   1.31
# 2   14.5  12.67  11.22   9.88    9.2    8.3    7.7    5.8    5.3   5.16
# 3    4.3   3.89   3.28   3.24    3.0    2.9    2.7    2.3    2.3   2.29
# 4    5.7   5.20   5.02   4.73    4.1    3.9    3.7    3.0    2.5   3.31

# %% [markdown]
# ## 2.3 查看是否有缺失值

# %%
df_marry.isnull().any()
# Out:
# 地区       False
# 2019年    False
# 2018年    False
# 2017年    False
# 2016年    False
# 2015年    False
# 2014年    False
# 2013年    False
# 2012年    False
# 2011年    False
# 2010年    False
# 2009年    False
# 2008年    False
# 2007年    False
# 2006年    False
# 2005年    False
# 2004年    False
# 2003年    False
# 2002年    False
# 2001年    False
# dtype: bool

# %% [markdown]
# **结婚登记数据没有缺失值。**

# %%
df_divorce.isnull().any()
# Out:
# 地区       False
# 2019年    False
# 2018年    False
# 2017年    False
# 2016年    False
# 2015年    False
# 2014年    False
# 2013年    False
# 2012年    False
# 2011年    False
# 2010年    False
# 2009年    False
# 2008年    False
# 2007年    False
# 2006年    False
# 2005年    False
# 2004年    False
# 2003年    False
# 2002年    False
# 2001年    False
# dtype: bool

# %% [markdown]
# **离婚登记数据没有缺失值。**

# %% [markdown]
# ## 2.4 新增列：结婚占比、离婚占比、离结率

# %%
# 2019年各地区离结率
df_tmp = pd.DataFrame()
df_tmp['地区'] = df_marry['地区']
df_tmp['结婚'] = df_marry['2019年']
df_tmp['离婚'] = df_divorce['2019年']
df_tmp['结婚占比'] = round(df_marry['2019年']*100 /(df_marry['2019年'] + df_divorce['2019年']), 2)
df_tmp['离婚占比'] = round(df_divorce['2019年']*100 /(df_marry['2019年'] + df_divorce['2019年']), 2)
df_tmp['离结率'] = round(df_tmp['离婚占比'] /(df_tmp['结婚占比']), 2)
df_tmp.head()
# Out:
#        地区     结婚     离婚   结婚占比   离婚占比   离结率
# 0     北京市  12.90   8.38  60.62  39.38  0.65
# 1     天津市   9.64   7.47  56.34  43.66  0.77
# 2     河北省  42.13  25.57  62.23  37.77  0.61
# 3     山西省  25.50   9.12  73.66  26.34  0.36
# 4  内蒙古自治区  16.18   9.98  61.85  38.15  0.62

# %% [markdown]
# # 3. 可视化
# ## 3.1 2019年各地区结婚离婚占比

# %%
# 阴影样式
itemstyle={
        'normal': {
            'shadowColor': 'rgba(0, 0, 0, .5)',  # 阴影颜色
            'shadowBlur': 5,  # 阴影大小
            'shadowOffsetY': 2,  # Y轴方向阴影偏移
            'shadowOffsetX': 2,  # x轴方向阴影偏移
            'borderColor': '#fff'
        }
    }

area = df_tmp['地区'].values.tolist()
marry_count = df_tmp['结婚占比'].values.tolist()
divorce_count = df_tmp['离婚占比'].values.tolist()

b1 = (
    Bar(
        init_opts=opts.InitOpts(
        width='800px', height='600px',
        )
    )
    .add_xaxis(area)
    .add_yaxis('结婚占比', marry_count, stack='stack1',itemstyle_opts=opts.ItemStyleOpts(color='#ed1941'))
    .add_yaxis('离婚占比', divorce_count, stack='stack1',itemstyle_opts=opts.ItemStyleOpts(color='#009ad6'))
    .set_series_opts(
        label_opts=opts.LabelOpts(
             is_show=True,
             position='inside'
        )
    )
    .set_global_opts(
        legend_opts=opts.LegendOpts(
            pos_right='10%',
            pos_top='2%',
            orient='horizontal',
        ),
        title_opts=opts.TitleOpts(
            title='2019年各地区结婚离婚占比',
            pos_top='2%'
        ),
    )
    .reversal_axis()
)
b1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="2cd4048b238b42daba654a0a7452da83" style="width:800px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_2cd4048b238b42daba654a0a7452da83 = echarts.init(
#                     document.getElementById('2cd4048b238b42daba654a0a7452da83'), 'white', {renderer: 'canvas'});
#                 var option_2cd4048b238b42daba654a0a7452da83 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u7ed3\u5a5a\u5360\u6bd4",
#             "legendHoverLink": true,
#             "data": [
#                 60.62,
#                 56.34,
#                 62.23,
#                 73.66,
#                 61.85,
#                 59.11,
#                 58.21,
#                 56.68,
#                 61.53,
#                 65.53,
#                 65.54,
#                 68.41,
#                 68.13,
#                 68.64,
#                 65.19,
#                 68.2,
#                 64.73,
#                 63.31,
#                 73.11,
#                 69.83,
#                 75.32,
#                 60.41,
#                 65.75,
#                 68.57,
#                 71.31,
#                 85.48,
#                 66.54,
#                 76.14,
#                 75.72,
#                 71.4,
#                 69.41
#             ],
#             "showBackground": false,
#             "stack": "stack1",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "color": "#ed1941"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u79bb\u5a5a\u5360\u6bd4",
#             "legendHoverLink": true,
#             "data": [
#                 39.38,
#                 43.66,
#                 37.77,
#                 26.34,
#                 38.15,
#                 40.89,
#                 41.79,
#                 43.32,
#                 38.47,
#                 34.47,
#                 34.46,
#                 31.59,
#                 31.87,
#                 31.36,
#                 34.81,
#                 31.8,
#                 35.27,
#                 36.69,
#                 26.89,
#                 30.17,
#                 24.68,
#                 39.59,
#                 34.25,
#                 31.43,
#                 28.69,
#                 14.52,
#                 33.46,
#                 23.86,
#                 24.28,
#                 28.6,
#                 30.59
#             ],
#             "showBackground": false,
#             "stack": "stack1",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "color": "#009ad6"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7ed3\u5a5a\u5360\u6bd4",
#                 "\u79bb\u5a5a\u5360\u6bd4"
#             ],
#             "selected": {
#                 "\u7ed3\u5a5a\u5360\u6bd4": true,
#                 "\u79bb\u5a5a\u5360\u6bd4": true
#             },
#             "show": true,
#             "right": "10%",
#             "top": "2%",
#             "orient": "horizontal",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5317\u4eac\u5e02",
#                 "\u5929\u6d25\u5e02",
#                 "\u6cb3\u5317\u7701",
#                 "\u5c71\u897f\u7701",
#                 "\u5185\u8499\u53e4\u81ea\u6cbb\u533a",
#                 "\u8fbd\u5b81\u7701",
#                 "\u5409\u6797\u7701",
#                 "\u9ed1\u9f99\u6c5f\u7701",
#                 "\u4e0a\u6d77\u5e02",
#                 "\u6c5f\u82cf\u7701",
#                 "\u6d59\u6c5f\u7701",
#                 "\u5b89\u5fbd\u7701",
#                 "\u798f\u5efa\u7701",
#                 "\u6c5f\u897f\u7701",
#                 "\u5c71\u4e1c\u7701",
#                 "\u6cb3\u5357\u7701",
#                 "\u6e56\u5317\u7701",
#                 "\u6e56\u5357\u7701",
#                 "\u5e7f\u4e1c\u7701",
#                 "\u5e7f\u897f\u58ee\u65cf\u81ea\u6cbb\u533a",
#                 "\u6d77\u5357\u7701",
#                 "\u91cd\u5e86\u5e02",
#                 "\u56db\u5ddd\u7701",
#                 "\u8d35\u5dde\u7701",
#                 "\u4e91\u5357\u7701",
#                 "\u897f\u85cf\u81ea\u6cbb\u533a",
#                 "\u9655\u897f\u7701",
#                 "\u7518\u8083\u7701",
#                 "\u9752\u6d77\u7701",
#                 "\u5b81\u590f\u56de\u65cf\u81ea\u6cbb\u533a",
#                 "\u65b0\u7586\u7ef4\u543e\u5c14\u81ea\u6cbb\u533a"
#             ]

# %% [markdown]
# ## 3.2 列数据逆序高亮

# %%
df_tmp = df_tmp.sort_values('离结率', ascending=False)
df_tmp.style.bar(subset=['离结率'],color='#ed1941')
# Out:
# <style  type="text/css" >
#     #T_f9bbaef0_00c6_11ec_8151_f63545f89789row0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed1941 100.0%, transparent 100.0%);
#         }    #T_f9bbaef0_00c6_11ec_8151_f63545f89789row1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed1941 98.3%, transparent 98.3%);
#         }    #T_f9bbaef0_00c6_11ec_8151_f63545f89789row2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed1941 91.7%, transparent 91.7%);
#         }    #T_f9bbaef0_00c6_11ec_8151_f63545f89789row3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed1941 86.7%, transparent 86.7%);
#         }    #T_f9bbaef0_00c6_11ec_8151_f63545f89789row4_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed1941 81.7%, transparent 81.7%);
#         }    #T_f9bbaef0_00c6_11ec_8151_f63545f89789row5_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed1941 80.0%, transparent 80.0%);
#         }    #T_f9bbaef0_00c6_11ec_8151_f63545f89789row6_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed1941 76.7%, transparent 76.7%);
#         }    #T_f9bbaef0_00c6_11ec_8151_f63545f89789row7_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed1941 75.0%, transparent 75.0%);
#         }    #T_f9bbaef0_00c6_11ec_8151_f63545f89789row8_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed1941 73.3%, transparent 73.3%);
#         }    #T_f9bbaef0_00c6_11ec_8151_f63545f89789row9_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed1941 68.3%, transparent 68.3%);
#         }    #T_f9bbaef0_00c6_11ec_8151_f63545f89789row10_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed1941 61.7%, transparent 61.7%);
#         }    #T_f9bbaef0_00c6_11ec_8151_f63545f89789row11_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed1941 60.0%, transparent 60.0%);
#         }    #T_f9bbaef0_00c6_11ec_8151_f63545f89789row12_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed1941 60.0%, transparent 60.0%);
#         }    #T_f9bbaef0_00c6_11ec_8151_f63545f89789row13_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed1941 60.0%, transparent 60.0%);
#         }    #T_f9bbaef0_00c6_11ec_8151_f63545f89789row14_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed1941 58.3%, transparent 58.3%);
#         }    #T_f9bbaef0_00c6_11ec_8151_f63545f89789row15_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed1941 55.0%, transparent 55.0%);
#         }    #T_f9bbaef0_00c6_11ec_8151_f63545f89789row16_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed1941 50.0%, transparent 50.0%);
#         }    #T_f9bbaef0_00c6_11ec_8151_f63545f89789row17_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed1941 50.0%, transparent 50.0%);
#         }    #T_f9bbaef0_00c6_11ec_8151_f63545f89789row18_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed1941 48.3%, transparent 48.3%);
#         }    #T_f9bbaef0_00c6_11ec_8151_f63545f89789row19_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed1941 48.3%, transparent 48.3%);
#         }    #T_f9bbaef0_00c6_11ec_8151_f63545f89789row20_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed1941 48.3%, transparent 48.3%);
#         }    #T_f9bbaef0_00c6_11ec_8151_f63545f89789row21_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed1941 45.0%, transparent 45.0%);
#         }    #T_f9bbaef0_00c6_11ec_8151_f63545f89789row22_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed1941 43.3%, transparent 43.3%);
#         }    #T_f9bbaef0_00c6_11ec_8151_f63545f89789row23_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed1941 38.3%, transparent 38.3%);
#         }    #T_f9bbaef0_00c6_11ec_8151_f63545f89789row24_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed1941 38.3%, transparent 38.3%);
#         }    #T_f9bbaef0_00c6_11ec_8151_f63545f89789row25_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed1941 33.3%, transparent 33.3%);
#         }    #T_f9bbaef0_00c6_11ec_8151_f63545f89789row26_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed1941 31.7%, transparent 31.7%);
#         }    #T_f9bbaef0_00c6_11ec_8151_f63545f89789row27_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed1941 26.7%, transparent 26.7%);
#         }    #T_f9bbaef0_00c6_11ec_8151_f63545f89789row28_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed1941 25.0%, transparent 25.0%);
#         }    #T_f9bbaef0_00c6_11ec_8151_f63545f89789row29_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed1941 23.3%, transparent 23.3%);
#         }    #T_f9bbaef0_00c6_11ec_8151_f63545f89789row30_col5 {
#             width:  10em;
#              height:  80%;
#         }</style><table id="T_f9bbaef0_00c6_11ec_8151_f63545f89789" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >地区</th>        <th class="col_heading level0 col1" >结婚</th>        <th class="col_heading level0 col2" >离婚</th>        <th class="col_heading level0 col3" >结婚占比</th>        <th class="col_heading level0 col4" >离婚占比</th>        <th class="col_heading level0 col5" >离结率</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f9bbaef0_00c6_11ec_8151_f63545f89789level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_f9bbaef0_00c6_11ec_8151_f63545f89789row0_col0" class="data row0 col0" >天津市</td>
#                         <td id="T_f9bbaef0_00c6_11ec_8151_f63545f89789row0_col1" class="data row0 col1" >9.64</td>
#                         <td id="T_f9bbaef0_00c6_11ec_8151_f63545f89789row0_col2" class="data row0 col2" >7.47</td>
#                         <td id="T_f9bbaef0_00c6_11ec_8151_f63545f89789row0_col3" class="data row0 col3" >56.34</td>
#                         <td id="T_f9bbaef0_00c6_11ec_8151_f63545f89789row0_col4" class="data row0 col4" >43.66</td>
#                         <td id="T_f9bbaef0_00c6_11ec_8151_f63545f89789row0_col5" class="data row0 col5" >0.77</td>
#             </tr>
#             <tr>
#                         <th id="T_f9bbaef0_00c6_11ec_8151_f63545f89789level0_row1" class="row_heading level0 row1" >7</th>
#                         <td id="T_f9bbaef0_00c6_11ec_8151_f63545f89789row1_col0" class="data row1 col0" >黑龙江省</td>
#                         <td id="T_f9bbaef0_00c6_11ec_8151_f63545f89789row1_col1" class="data row1 col1" >24.44</td>
#                         <td id="T_f9bbaef0_00c6_11ec_8151_f63545f89789row1_col2" class="data row1 col2" >18.68</td>
#                         <td id="T_f9bbaef0_00c6_11ec_8151_f63545f897

# %% [markdown]
# ## 3.3 离结率柱状图

# %%
sort_info = df_tmp.sort_values('离结率', ascending=True)
b1 = (
    Bar(init_opts=opts.InitOpts(
        width='800px', height='600px',))
    .add_xaxis(list(sort_info['地区'])[-20:])
    .add_yaxis('', sort_info['离结率'].values.tolist()[-20:],
               category_gap='30%',
               itemstyle_opts={
               'normal': {
                   'shadowColor': 'rgba(0, 0, 0, .5)',  # 阴影颜色
                   'shadowBlur': 5,  # 阴影大小
                   'shadowOffsetY': 2,  # Y轴方向阴影偏移
                   'shadowOffsetX': 2,  # x轴方向阴影偏移
                   'borderColor': '#fff'
                   }
               }
              )
    .reversal_axis()
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(is_show=False),    
        yaxis_opts=opts.AxisOpts(is_show=False,
            axisline_opts=opts.AxisLineOpts(is_show=False),
            axistick_opts=opts.AxisTickOpts(is_show=False)
        ),
        title_opts=opts.TitleOpts(
            title='离结率 TOP20',
            pos_left='9%',
            pos_top='4%',
            title_textstyle_opts=opts.TextStyleOpts(
                color='#ed1941', font_size=16)
        ),
        visualmap_opts=opts.VisualMapOpts(
            is_show=False,
            max_=20,
            series_index=0,
        ),
     )
    .set_series_opts(
        itemstyle_opts={
            "normal": {
                "color": JsCode(
                    """new echarts.graphic.LinearGradient(0, 0, 0, 1, [{
                offset: 0,
                color: '#ed1941'
            }, {
                offset: 1,
                color: '#009ad6'
            }], false)"""
                ),
                "barBorderRadius": [30, 30, 30, 30],
                "shadowColor": "rgb(0, 160, 221)",
            }
        },
        label_opts=opts.LabelOpts(position="insideLeft",
                                              font_size=10,
                                              vertical_align='middle',
                                              horizontal_align='left',
                                              font_weight='bold',
                                              formatter='{b}: {c}'))
)

b1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="abcf96b945f64b6ea6acf24d5ff9cdd6" style="width:800px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_abcf96b945f64b6ea6acf24d5ff9cdd6 = echarts.init(
#                     document.getElementById('abcf96b945f64b6ea6acf24d5ff9cdd6'), 'white', {renderer: 'canvas'});
#                 var option_abcf96b945f64b6ea6acf24d5ff9cdd6 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
#                 0.46,
#                 0.46,
#                 0.47,
#                 0.47,
#                 0.5,
#                 0.52,
#                 0.53,
#                 0.53,
#                 0.53,
#                 0.54,
#                 0.58,
#                 0.61,
#                 0.62,
#                 0.63,
#                 0.65,
#                 0.66,
#                 0.69,
#                 0.72,
#                 0.76,
#                 0.77
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "30%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "insideLeft",
#                 "margin": 8,
#                 "fontSize": 10,
#                 "fontWeight": "bold",
#                 "align": "left",
#                 "verticalAlign": "middle",
#                 "formatter": "{b}: {c}"
#             },
#             "itemStyle": {
#                 "normal": {
#                     "color": new echarts.graphic.LinearGradient(0, 0, 0, 1, [{                offset: 0,                color: '#ed1941'            }, {                offset: 1,                color: '#009ad6'            }], false),
#                     "barBorderRadius": [
#                         30,
#                         30,
#                         30,
#                         30
#                     ],
#                     "shadowColor": "rgb(0, 160, 221)"
#                 }
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": false,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": false,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLine": {
#                 "show": false,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0
#             },
#             "axisTick": {
#                 "show": false,
#                 "alignWithLabel": false,
#                 "inside": false
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5b89\u5fbd\u7701",
#                 "\u6c5f\u897f\u7701",
#                 "\u798f\u5efa\u7701",
#                 "\u6cb3\u5357\u7701",
#                 "\u9655\u897f\u7701",
#                 "\u56db\u5ddd\u7701",
#                 "\u5c71\u4e1c\u7701",
#                 "\u6d59\u6c5f\u7701",
#                 "\u6c5f\u82cf\u7701",
#                 "\u6e56\u5317\u7701",
#                 "\u6e56\u5357\u7701",
#                 "\u6cb3\u5317\u7701",
#                 "\u5185\u8499\u53e4\u81ea\u6cbb\u533a",
#                 "\u4e0a\u6d77\u5e02",
#                 "\u5317\u4eac\u5e02",
#                 "\u91cd\u5e86\u5e02",
#                 "\u8fbd\u5b81\u7701",
#                 "\u5409\u6797\u7701",
#                 "\u9ed1\u9f99\u6c5f\u7701",
#                 "\u5929\u6d25\u5e02"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "\u79bb\u7ed3\u7387 TOP20",
#             "left": "9%",
#             "top": "4%",
#             "padding": 5,
#             "itemGap": 10,
#             "textStyle": {
#                 "color": "#ed1941",
#                 "fontSize": 16
#             }
#         }
#     ],
#     "visualMap": {
#         "show": false,
#         "type": "continuous",
#         "min": 0,
#         "max": 20,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "seriesIndex": 0,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_abcf96b945f64b6ea6acf24d5ff9cdd6.setOption(option_abcf96b945f64b6ea6acf24d5ff9cdd6);
#         });
#     </script>

# %%
print('全国共有{}个省市地区离结率超过50%，这已经是相当高了'.format(len(df_tmp[df_tmp['离结率'] > 0.5])))
# Out:
# 全国共有15个省市地区离结率超过50%，这已经是相当高了

# %% [markdown]
# **离结率超过50%的城市：**

# %%
df_tmp[df_tmp['离结率'] > 0.5]['地区']
# Out:
# 1      天津
# 7     黑龙江
# 6      吉林
# 5      辽宁
# 21     重庆
# 0      北京
# 8      上海
# 4     内蒙古
# 2      河北
# 17     湖南
# 16     湖北
# 9      江苏
# 10     浙江
# 14     山东
# 22     四川
# Name: 地区, dtype: object

# %% [markdown]
# ## 3.4 天津历年结婚/离婚登记数据
# 可以自行查看自己所在城市数据，这里我用了离结率第一的天津市

# %%
# 线性渐变
color_js0 = """new echarts.graphic.LinearGradient(0, 1, 0, 0,
    [{offset: 0, color: '#FFFFFF'}, {offset: 1, color: '#ed1941'}], false)"""

color_js1 = """new echarts.graphic.LinearGradient(0, 1, 0, 0,
    [{offset: 0, color: '#FFFFFF'}, {offset: 1, color: '#009ad6'}], false)"""


city = '天津市'
b2 = (
    Bar()
    .add_xaxis(df_divorce.columns[1:].values.tolist())
    .add_yaxis(
        series_name="结婚登记",
        y_axis=df_marry[df_marry['地区']==city].values[0][1:].tolist(),
        markpoint_opts=opts.MarkPointOpts(
            data=[
                opts.MarkPointItem(type_="max", name="最大值"),
                opts.MarkPointItem(type_="min", name="最小值"),
            ]
        ),
        itemstyle_opts=opts.ItemStyleOpts(color=JsCode(color_js0))
    )
    .add_yaxis(
        series_name="离婚登记",
        y_axis=df_divorce[df_divorce['地区']=='北京市'].values[0][1:].tolist(),
        markpoint_opts=opts.MarkPointOpts(
            data=[
                opts.MarkPointItem(type_="max", name="最大值"),
                opts.MarkPointItem(type_="min", name="最小值"),
            ]
        ),
        itemstyle_opts=opts.ItemStyleOpts(color=JsCode(color_js1))
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title=""),
        tooltip_opts=opts.TooltipOpts(trigger="axis"),
        xaxis_opts=opts.AxisOpts(name="年份",type_="category", 
                                 boundary_gap=True,
                                 axisline_opts=opts.AxisLineOpts(is_show=True,
                                                                 linestyle_opts=opts.LineStyleOpts(width=4, color='#DB7093')),
                                 axislabel_opts=opts.LabelOpts(rotate=45)),
        yaxis_opts=opts.AxisOpts(
                axislabel_opts=opts.LabelOpts(formatter="{value} /万对"),
                name=f'{city}历年结婚/离婚登记',            
                is_scale=True,
                name_textstyle_opts=opts.TextStyleOpts(font_size=14,font_weight='bold',color='#FF1493'),
                splitline_opts=opts.SplitLineOpts(is_show=True, 
                                                  linestyle_opts=opts.LineStyleOpts(type_='dashed')),
                axisline_opts=opts.AxisLineOpts(is_show=False,
                                        linestyle_opts=opts.LineStyleOpts(width=2, color='#DB7093'))
            ),
        legend_opts=opts.LegendOpts(is_show=True, pos_top='2%', legend_icon='roundRect'),
    )
)
b2.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="cdc6b2e9289b4eb9ad0b0e619387e75c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_cdc6b2e9289b4eb9ad0b0e619387e75c = echarts.init(
#                     document.getElementById('cdc6b2e9289b4eb9ad0b0e619387e75c'), 'white', {renderer: 'canvas'});
#                 var option_cdc6b2e9289b4eb9ad0b0e619387e75c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u7ed3\u5a5a\u767b\u8bb0",
#             "legendHoverLink": true,
#             "data": [
#                 9.64,
#                 9.75,
#                 9.51,
#                 9.82,
#                 10.12,
#                 9.94,
#                 10.26,
#                 10.14,
#                 10.41,
#                 8.7,
#                 10.4,
#                 8.93,
#                 7.57,
#                 8.4,
#                 6.4,
#                 7.7,
#                 6.3,
#                 5.4,
#                 5.79
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u6700\u5927\u503c",
#                         "type": "max"
#                     },
#                     {
#                         "name": "\u6700\u5c0f\u503c",
#                         "type": "min"
#                     }
#                 ]
#             },
#             "itemStyle": {
#                 "color": new echarts.graphic.LinearGradient(0, 1, 0, 0,    [{offset: 0, color: '#FFFFFF'}, {offset: 1, color: '#ed1941'}], false)
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u79bb\u5a5a\u767b\u8bb0",
#             "legendHoverLink": true,
#             "data": [
#                 8.38,
#                 7.41,
#                 8.06,
#                 10.58,
#                 8.22,
#                 6.56,
#                 6.46,
#                 4.86,
#                 4.35,
#                 4.4,
#                 4.13,
#                 3.76,
#                 3.66,
#                 3.6,
#                 3.4,
#                 3.3,
#                 3.1,
#                 2.8,
#                 2.77
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u6700\u5927\u503c",
#                         "type": "max"
#                     },
#                     {
#                         "name": "\u6700\u5c0f\u503c",
#                         "type": "min"
#                     }
#                 ]
#             },
#             "itemStyle": {
#                 "color": new echarts.graphic.LinearGradient(0, 1, 0, 0,    [{offset: 0, color: '#FFFFFF'}, {offset: 1, color: '#009ad6'}], false)
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7ed3\u5a5a\u767b\u8bb0",
#                 "\u79bb\u5a5a\u767b\u8bb0"
#             ],
#             "selected": {
#                 "\u7ed3\u5a5a\u767b\u8bb0": true,
#                 "\u79bb\u5a5a\u767b\u8bb0": true
#             },
#             "show": true,
#             "top": "2%",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "icon": "roundRect"
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "axis",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "type": "category",
#             "name": "\u5e74\u4efd",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLine": {
#                 "show": true,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 4,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": "#DB7093"
#                 }
#             },
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": 45,
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "boundaryGap": true,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "2019\u5e74",
#                 "2018\u5e74",
#                 "2017\u5e74",
#                 "2016\u5e74",
#                 "2015\u5e74",
#                 "2014\u5e74",
#                 "2013\u5e74",
#                 "2012\u5e74",
#                 "2011\u5e74",
#                 "2010\u5e74",
#                 "2009\u5e74",
#                 "2008\u5e74",
#                 "2007\u5e74",
#                 "2006\u5e74",
#                 "2005\u5e74",
#                 "2004\u5e74",
#                 "2003\u5e74",
#                 "2002\u5e74",
#                 "2001\u5e74"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "\u5929\u6d25\u5e02\u5386\u5e74\u7ed3\u5a5a/\u79bb\u5a5a\u767b\u8bb0",
#             "show": true,
#             "scale": true,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "nameTextStyle": {
#                 "color": "#FF1493",
#                 "fontWeight": "bold",

# %% [markdown]
# ## 3.5 2019年各地区离结率数据热力图

# %%
# 线性渐变
color_js = """new echarts.graphic.LinearGradient(0, 0, 1, 0,
    [{offset: 0, color: '#009ad6'}, {offset: 1, color: '#ed1941'}], false)"""
df_tmp = df_tmp.replace('省', '', regex=True).replace('市', '', regex=True).replace('自治区', '', regex=True).replace('壮族', '', regex=True).replace('维吾尔', '', regex=True).replace('回族', '', regex=True)
map_chart = Map(init_opts=opts.InitOpts(theme='light',
                                        width='800px',
                                        height='600px'))
map_chart.add('离婚/结婚',
              [list(z) for z in zip(df_tmp['地区'].values.tolist(), df_tmp['离结率'].values.tolist())],
              maptype='china',
              is_map_symbol_show=False,
              itemstyle_opts={
                  'normal': {
                      'shadowColor': 'rgba(0, 0, 0, .5)',  # 阴影颜色
                      'shadowBlur': 5,  # 阴影大小
                      'shadowOffsetY': 0,  # Y轴方向阴影偏移
                      'shadowOffsetX': 0,  # x轴方向阴影偏移
                      'borderColor': '#fff'
                  }
              }
              )
map_chart.set_global_opts(
    visualmap_opts=opts.VisualMapOpts(
        is_show=True,
        is_piecewise=True,
        min_ = 0,
        max_ = 1,
        split_number = 5,
        series_index=0,
        pos_top='70%',
        pos_left='10%',
        range_text=['离结率', ''],
        pieces=[
            {'max':1.0, 'min':0.8, 'label':'0.8-1.0', 'color': '#990000'},
            {'max':0.8, 'min':0.6, 'label':'0.6-0.8', 'color': '#CD5C5C'},
            {'max':0.6, 'min':0.4, 'label':'0.4-0.6', 'color': '#F08080'},
            {'max':0.4, 'min':0.2, 'label':'0.2-0.4', 'color': '#FFCC99'},
            {'max':0.2, 'min':0.0, 'label':'0.0-0.2', 'color': '#FFE4E1'},
           ],
    ),
    legend_opts=opts.LegendOpts(is_show=False),
    tooltip_opts=opts.TooltipOpts(
        is_show=True,
        trigger='item',
        formatter='{b}:{c}'
    ),
    title_opts=dict(
        text='2001-2019年各地区离结率',
        left='center',
        top='5%',
        textStyle=dict(
            color='#DC143C'))
)
map_chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="47a067d76f0c46cdaadc32dc974eed61" style="width:800px; height:600px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_47a067d76f0c46cdaadc32dc974eed61 = echarts.init(
#                     document.getElementById('47a067d76f0c46cdaadc32dc974eed61'), 'light', {renderer: 'canvas'});
#                 var option_47a067d76f0c46cdaadc32dc974eed61 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "map",
#             "name": "\u79bb\u5a5a/\u7ed3\u5a5a",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 0.77
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 0.76
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 0.72
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 0.69
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 0.66
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 0.65
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 0.63
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 0.62
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 0.61
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 0.58
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 0.54
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 0.53
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 0.53
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 0.53
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 0.52
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 0.5
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 0.47
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 0.47
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 0.46
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 0.46
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 0.46
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 0.44
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 0.43
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 0.4
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 0.4
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 0.37
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 0.36
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 0.33
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 0.32
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 0.31
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 0.17
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": false,
#             "itemStyle": {
#                 "normal": {
#                     "shadowColor": "rgba(0, 0, 0, .5)",
#                     "shadowBlur": 5,
#                     "shadowOffsetY": 0,
#                     "shadowOffsetX": 0,
#                     "borderColor": "#fff"
#                 }
#             },
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u79bb\u5a5a/\u7ed3\u5a5a"
#             ],
#             "selected": {
#                 "\u79bb\u5a5a/\u7ed3\u5a5a": true
#             },
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "formatter": "{b}:{c}",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": {
#         "text": "2001-2019\u5e74\u5404\u5730\u533a\u79bb\u7ed3\u7387",
#         "left": "center",
#         "top": "5%",
#         "textStyle": {
#             "color": "#DC143C"
#         }
#     },
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 0,
#         "max": 1,
#         "text": [
#             "\u79bb\u7ed3\u7387",
#             ""
#         ],
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "seriesIndex": 0,
#         "orient": "vertical",
#         "left": "10%",
#         "top": "70%",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 14,
#         "borderWidth": 0,
#         "pieces": [
#             {
#                 "max": 1.0,
#                 "min": 0.8,
#                 "label": "0.8-1.0",
#                 "color": "#990000"
#             },
#             {
#                 "max": 0.8,
#                 "min": 0.6,
#                 "label": "0.6-0.8",
#                 "color": "#CD5C5C"
#             },
#             {
#                 "max": 0.6,
#                 "min": 0.4,
#                 "label": "0.4-0.6",
#                 "color": "#F08080"
#             },
#             {
#                 "max": 0.4,
#                 "min": 0.2,
#                 "label": "0.2-0.4",
#                 "color": "#FFCC99"
#             },
#             {
#                 "max": 0.2,
#                 "min": 0.0,
#                 "label": "0.0-0.2",
#                 "color": "#FFE4E1"
#             }
#         ]
#     }
# };
#                 chart_47a067d76f0c46cdaadc32dc974eed61.setOption(option_47a067d76f0c46cdaadc32dc974eed61);
#         });
#     </script>

# %% [markdown]
# ## 3.6 历年全国结婚离婚登记趋势

# %%
df_marry.loc["总计"] =df_marry.apply(lambda x:x.sum()) 
df_divorce.loc["总计"] =df_divorce.apply(lambda x:x.sum()) 
df_marry.loc['总计','地区'] = '全国'
df_divorce.loc['总计','地区'] = '全国'
df_marry[df_marry['地区'] == '全国']
# Out:
#     地区   2019年    2018年   2017年    2016年    2015年    2014年    2013年    2012年  \
# 总计  全国  927.33  1013.94  1063.1  1142.84  1224.71  1306.72  1346.93  1323.58
#
#       2011年   2010年    2009年   2008年   2007年  2006年  2005年   2004年   2003年  \
# 总计  1302.35  1241.2  1212.43  1098.3  991.38  944.9  823.1  867.21  810.64
#
#     2002年   2001年
# 总计  786.1  804.95

# %%
df_divorce[df_marry['地区'] == '全国']
# Out:
#     地区   2019年   2018年   2017年   2016年   2015年   2014年   2013年   2012年  \
# 总计  全国  470.09  446.07  437.35  415.81  384.14  363.65  350.02  310.42
#
#      2011年  2010年   2009年   2008年   2007年  2006年  2005年  2004年  2003年  2002年  \
# 总计  287.38  267.8  246.78  226.89  209.83  191.0  178.4  166.4  132.4  117.6
#
#      2001年
# 总计  125.07

# %%
# 背景色
background_color_js = """
new echarts.graphic.RadialGradient(0.3, 0.3, 0.8, [{offset: 0,color: '#f7f8fa'}, 
{offset: 1,color: '#cdd0d5'}])
"""

# 线条样式
linestyle_dic = { 'normal': {
                    'width': 4,  
                    'shadowColor': '#696969', 
                    'shadowBlur': 10,  
                    'shadowOffsetY': 10,  
                    'shadowOffsetX': 10,  
                    }
                }
l1 = (
    Line(init_opts=opts.InitOpts(bg_color=JsCode(background_color_js)))
    .add_xaxis(xaxis_data=df_divorce.columns[1:][::-1])
    .add_yaxis(
        series_name="结婚登记",
        y_axis=[round(i,2) for i in df_marry.loc["总计"].values.tolist()[1:]],
        symbol_size=8,
        is_smooth=True,
        color="#009ad6",
    )
    .add_yaxis(
        series_name="离婚登记",
        y_axis=[round(i,2) for i in df_divorce.loc["总计"].values.tolist()[1:]],
        symbol_size=8,
        is_smooth=True,        
        color="#ed1941",
    )
    # 系列配置项
    .set_series_opts(linestyle_opts=linestyle_dic,
                     areastyle_opts=opts.AreaStyleOpts(opacity=0.6),
                     label_opts=opts.LabelOpts(is_show=False),
                     markline_opts=opts.MarkLineOpts(data=[opts.MarkLineItem(type_="average")]),
                     markpoint_opts=opts.MarkPointOpts(
                        data=[opts.MarkPointItem(type_="max"), opts.MarkPointItem(type_="min")],
                        symbol_size=[65, 50],
                        label_opts=opts.LabelOpts(position="inside", color="#fff", font_size=10)
                        ),
                    )
    # 通用配置项
    .set_global_opts(
        title_opts=opts.TitleOpts(
                title='历年全国结/离婚登记趋势',
                pos_top='2%',
                title_textstyle_opts=opts.TextStyleOpts(color='#4169E1', font_size=20)),
        tooltip_opts=opts.TooltipOpts(trigger="axis"),
        xaxis_opts=opts.AxisOpts(name="",type_="category", 
                         boundary_gap=True,
                         axisline_opts=opts.AxisLineOpts(is_show=True,
                                                         linestyle_opts=opts.LineStyleOpts(width=2, color='#DB7093')),
                         axislabel_opts=opts.LabelOpts(rotate=45)),
        yaxis_opts=opts.AxisOpts(
                axislabel_opts=opts.LabelOpts(formatter="{value} /万对"),
                is_scale=True,
                name_textstyle_opts=opts.TextStyleOpts(font_size=12,font_weight='bold',color='#FF1493'),
                splitline_opts=opts.SplitLineOpts(is_show=True, 
                                                  linestyle_opts=opts.LineStyleOpts(type_='dashed')),
                axisline_opts=opts.AxisLineOpts(is_show=False,
                                        linestyle_opts=opts.LineStyleOpts(width=2, color='#DB7093'))
            ),
        # 图例样式
        legend_opts=opts.LegendOpts(is_show=True, pos_right='1%', pos_top='2%',legend_icon='roundRect'),
    )
)
l1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="1da2c92219444790843c36737b03336d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_1da2c92219444790843c36737b03336d = echarts.init(
#                     document.getElementById('1da2c92219444790843c36737b03336d'), 'white', {renderer: 'canvas'});
#                 var option_1da2c92219444790843c36737b03336d = {
#     "backgroundColor": new echarts.graphic.RadialGradient(0.3, 0.3, 0.8, [{offset: 0,color: '#f7f8fa'}, {offset: 1,color: '#cdd0d5'}]),
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#ed1941",
#         "#009ad6",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u7ed3\u5a5a\u767b\u8bb0",
#             "connectNulls": false,
#             "symbolSize": 8,
#             "showSymbol": true,
#             "smooth": true,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2001\u5e74",
#                     927.33
#                 ],
#                 [
#                     "2002\u5e74",
#                     1013.94
#                 ],
#                 [
#                     "2003\u5e74",
#                     1063.1
#                 ],
#                 [
#                     "2004\u5e74",
#                     1142.84
#                 ],
#                 [
#                     "2005\u5e74",
#                     1224.71
#                 ],
#                 [
#                     "2006\u5e74",
#                     1306.72
#                 ],
#                 [
#                     "2007\u5e74",
#                     1346.93
#                 ],
#                 [
#                     "2008\u5e74",
#                     1323.58
#                 ],
#                 [
#                     "2009\u5e74",
#                     1302.35
#                 ],
#                 [
#                     "2010\u5e74",
#                     1241.2
#                 ],
#                 [
#                     "2011\u5e74",
#                     1212.43
#                 ],
#                 [
#                     "2012\u5e74",
#                     1098.3
#                 ],
#                 [
#                     "2013\u5e74",
#                     991.38
#                 ],
#                 [
#                     "2014\u5e74",
#                     944.9
#                 ],
#                 [
#                     "2015\u5e74",
#                     823.1
#                 ],
#                 [
#                     "2016\u5e74",
#                     867.21
#                 ],
#                 [
#                     "2017\u5e74",
#                     810.64
#                 ],
#                 [
#                     "2018\u5e74",
#                     786.1
#                 ],
#                 [
#                     "2019\u5e74",
#                     804.95
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 4,
#                     "shadowColor": "#696969",
#                     "shadowBlur": 10,
#                     "shadowOffsetY": 10,
#                     "shadowOffsetX": 10
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0.6
#             },
#             "markPoint": {
#                 "symbolSize": [
#                     65,
#                     50
#                 ],
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8,
#                     "fontSize": 10
#                 },
#                 "data": [
#                     {
#                         "type": "max"
#                     },
#                     {
#                         "type": "min"
#                     }
#                 ]
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "type": "average"
#                     }
#                 ]
#             },
#             "zlevel": 0,
#             "z": 0,
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u79bb\u5a5a\u767b\u8bb0",
#             "connectNulls": false,
#             "symbolSize": 8,
#             "showSymbol": true,
#             "smooth": true,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2001\u5e74",
#                     470.09
#                 ],
#                 [
#                     "2002\u5e74",
#                     446.07
#                 ],
#                 [
#                     "2003\u5e74",
#                     437.35
#                 ],
#                 [
#                     "2004\u5e74",
#                     415.81
#                 ],
#                 [
#                     "2005\u5e74",
#                     384.14
#                 ],
#                 [
#                     "2006\u5e74",
#                     363.65
#                 ],
#                 [
#                     "2007\u5e74",
#                     350.02
#                 ],
#                 [
#                     "2008\u5e74",
#                     310.42
#                 ],
#                 [
#                     "2009\u5e74",
#                     287.38
#                 ],
#                 [
#                     "2010\u5e74",
#                     267.8
#                 ],
#                 [
#                     "2011\u5e74",
#                     246.78
#                 ],
#                 [
#                     "2012\u5e74",
#                     226.89
#                 ],
#                 [
#                     "2013\u5e74",
#                     209.83
#                 ],
#                 [
#                     "2014\u5e74",
#                     191.0
#                 ],
#                 [
#                     "2015\u5e74",
#                     178.4
#                 ],
#                 [
#                     "2016\u5e74",
#                     166.4
#                 ],
#                 [
#                     "2017\u5e74",
#                     132.4
#                 ],
#                 [
#                     "2018\u5e74",
#                     117.6
#                 ],
#                 [
#                     "2019\u5e74",
#                     125.07
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 4,
#                     "shadowColor": "#696969",
#                     "shadowBlur": 10,
#                     "shadowOffsetY": 10,
#                     "shadowOffsetX": 10
#                 }
#             },
#             "areaStyle": {

# %% [markdown]
# # 总结
# **1.结婚登记数量前五地区：河南、广东、四川、江苏、安徽
# 2.离婚登记数量前五地区：河南、四川、江苏、山东、河北
# 3.全国结婚登记数量从2007年开始出现持续下降趋势
# 4.北方地区离结率较南方地区高出不少
# 待续。。**
#
# # 数据集获取
# 👉 [【**2001-2019全国各地区民政登记数据**】](https://www.heywhale.com/mw/dataset/611df906aca2460017a7684b/file)
#
# 🚀 欢迎感兴趣的小伙伴 👉 ** *Fork、点赞*  ~ ~ ~**
